# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.autograd import Variable
import torch.nn.functional as F
from IPython.core.debugger import Tracer

from adversarialbox.attacks import FGSMAttack, LinfPGDAttack, CertAttack
from adversarialbox.train import adv_train, FGSM_train_rnd
from adversarialbox.utils import to_var, pred_batch, test
torch.set_default_tensor_type('torch.cuda.FloatTensor')
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)
np.random.seed(0)

# %%
N = 10000
x_init = np.random.randn(N, 2)
x = []
y = []
for ii in range(N):
    if np.linalg.norm(x_init[ii,:]) > np.sqrt(2)/1.3 and np.linalg.norm(x_init[ii,:]) < np.sqrt(2)*1.3:
        continue
    x.append(x_init[ii,:])
    y.append(0.5*np.sign(np.linalg.norm(x_init[ii,:]) - np.sqrt(2))+0.5)

x = np.stack(x).astype(np.float32)
y = np.array(y).astype(np.int)
print(x.shape)
print(y)
colormap = np.array(['r', 'g', 'b'])
print(colormap[y+1])

plt.scatter(x[:,0], x[:,1], c = colormap[y+1])
plt.xlim([-3,3])
plt.ylim([-3,3])
print(np.max(y))
# Out:
# (6338, 2)
# [1 1 0 ..., 1 0 0]
# ['b' 'b' 'g' ..., 'b' 'g' 'g']
# 1

# %% [markdown]
#  adversarial attack

# %%
import copy
import numpy as np
from collections import Iterable
from scipy.stats import truncnorm
import torch
import torch.nn as nn
from adversarialbox.utils import to_var
from sampler.sghmc import SGHMC
class BayesWRM(object):
    def __init__(self, model=None, model_list=None, epsilon=0.5, k=15, a=1, gamma=2, T=1e-3, random_start=False):
        """
        Attack parameter initialization. The attack performs k steps of
        size a, while always staying within epsilon from the initial
        point.
        https://github.com/MadryLab/mnist_challenge/blob/master/pgd_attack.py
        """
        self.model = model
        self.epsilon = epsilon
        self.k = k
        self.a = a
        self.rand = random_start
        self.gamma = gamma
        self.loss_fn = nn.CrossEntropyLoss()
        
        self.T = T #Temperature
        self.model_list = model_list

    def perturb(self, X_nat, y):
        """
        Given examples (X_nat, y), returns adversarial
        examples within epsilon of X_nat in l_infinity norm.
        """
        if self.rand:
            X = X_nat + np.random.uniform(-self.epsilon, self.epsilon,
                X_nat.shape).astype('float32')
        else:
            X = np.copy(X_nat)
        Sz = 2
        Stheta = 2
        MC = 15
        #List of numpy arrays
        z_list = [copy.deepcopy(X) for i in range(Sz)]
        
        
        y_var = to_var(torch.LongTensor(y))
        loss_fn = nn.CrossEntropyLoss()
        for k in range(Sz):
            
            class ZNN(nn.Module):
                def __init__(self):
                    super(ZNN, self).__init__()
                    self.Z_var = nn.Parameter(torch.from_numpy(z_list[k].astype(np.float32)).cuda(), requires_grad=True)
                    
                def forward(self, model_list, gamma):
                    
                    Z_var0 = Variable(torch.from_numpy(z_list[k].astype(np.float32)).cuda(), requires_grad=False)
                    total_loss = 0
                    for i in range(Stheta):
                        scores = model_list[i](self.Z_var)
                        #loss = self.loss_fn(scores, y_var) - self.gamma*torch.sum((self.Z_var-Z_var0)**2)
                        #Tracer()()
                        loss = loss_fn(scores, y_var) - gamma*torch.sum((self.Z_var-Z_var0)**2)
                    total_loss = total_loss + loss
                    return total_loss
                
            znn = ZNN()         
            #optimizer = torch.optim.SGD(znn.parameters(), lr=1e-4)  
            optimizer = SGHMC(znn.parameters(), config=dict(lr=1e-4))
            
            def helper():
                def feval():
                    total_loss = znn(model_list=self.model_list, gamma=self.gamma)
                    optimizer.zero_grad()
                    total_loss.backward()
                    return total_loss #TODO return loss for extension
                return feval
            total_loss = optimizer.step(helper())
            z_list[k] = znn.Z_var.data.cpu().numpy()
            
            '''
            #Langevin MC steps
            for m in range(MC):
                #Aggregate loss gradients
                total_loss = znn(model_list=self.model_list, gamma=self.gamma)
                optimizer.zero_grad()
                total_loss.backward()
                #Z_var = Z_var.type(torch.cuda.FloatTensor)
                #Tracer()()
            '''
            
            
            
                
        print('Sz step finished')
        return z_list
        
        print('maximum diff adv', np.max(np.abs(X-X_nat)))

# %%
#Without adversarial
advtraining = True
WRM = False
Stheta = 2
#adversary = LinfPGDAttack()
if WRM is True:
    adversary = BayesWRM(a=1e5, k=15, epsilon=10, gamma=2, T=1e-1)
else:
    adversary = BayesWRM(a=1e5, k=15, epsilon=10, gamma=0, T=1e-1)

from sampler.sghmc import SGHMC
#T=0.01
T=0.0
#TODO:add cert adv attack
#TODO:add x_adv example display
x_adv_set = []
y_adv_set = []


x_input = torch.from_numpy(x).float().cuda()
y_label = torch.from_numpy(y.astype(np.float)).float().cuda()
#net = nn.Sequential(nn.Linear(2, 4), nn.ELU(), nn.Linear(4, 2), nn.ELU(), nn.Linear(2, 2))
net = nn.Sequential(nn.Linear(2, 4), nn.ReLU(), nn.Linear(4, 2), nn.ReLU(), nn.Linear(2, 2))

#deep copy the original models
import copy
model_list=[copy.deepcopy(net) for i in range(Stheta)]

criterion = nn.CrossEntropyLoss()

#optimizer = torch.optim.Adam(net.parameters(), lr=0.01)
#optimizer = SGHMC(net.parameters(), lr=0.01)

for epoch in range(500):
   
    x_var, y_var = to_var(x_input), to_var(y_label.long())
    y_hat = net(x_var)
    loss = criterion(y_hat, y_var)
    

    
    y_pred = pred_batch(x_input.cpu(), net)         
    x_adv = x_input.cpu()
        
    x_adv = adv_train(X=x_adv, y=y_label.cpu().long(), model=model_list, criterion=criterion, adversary=adversary)   
    
    #Tracer()()
    if type(x_adv) is list:
        #Use the Bayesian setting
        for i in range(len(model_list)):
            #optimizer = torch.optim.Adam(model_list[i].parameters(), lr=0.01)
            optimizer = SGHMC(model_list[i].parameters(), config=dict(lr=0.5))
            def helper():
                def feval():
                    loss_adv = 0
                    for k in range(len(x_adv)):
                        x_adv_var = to_var(torch.from_numpy(x_adv[k].astype(np.float32)))
                        #loss_adv = loss_adv + criterion(net(x_adv_var), y_var)
                        loss_adv = loss_adv + criterion(model_list[i](x_adv_var), y_var)
                    optimizer.zero_grad()
                    loss_adv.backward()
                    
                    return loss_adv #TODO return loss for extension
                return feval
            #Tracer()()
            loss_adv = optimizer.step(helper())
            print('Epoch:', epoch, 'model:', i, 'loss', loss_adv.data.cpu().numpy()[0])
    '''
    Tracer()()  
    x_adv_set.append(x_adv.numpy())
    y_adv_set.append(y_label.cpu().numpy())
    
    Tracer()()
    x_adv_var = to_var(x_adv)
    loss_adv = criterion(net(x_adv_var), y_var)
    
    
    #loss_total = (loss + loss_adv)/2.0
    if advtraining is True:
        loss_total = loss_adv
    else:
        loss_total = loss
    #loss_total = loss
    optimizer.zero_grad()
    loss_total.backward()
    optimizer.step()
    #Tracer()()
    '''
    #loss_total = loss_adv
    #print('Epoch', epoch, 'loss total', loss_total.data.cpu().numpy()[0])
    '''
    if advtraining is True:
        #racer()()
        print('Epoch', epoch, 'input max diff', np.max(x_input.cpu().numpy()-x_adv.numpy()), 'loss total', loss_total.data.cpu().numpy()[0], 'loss', loss.data.cpu().numpy()[0], 'loss_adv', loss_adv.data.cpu().numpy()[0])
    else:
        print('Epoch', epoch, 'loss total', loss_total.data.cpu().numpy()[0])
    '''
print('Adversarial Trainining Finished')
# Out:
# Sz step finished
# Epoch: 0 model: 0 loss 1.36614
# Epoch: 0 model: 1 loss 1.36614
# Sz step finished
# Epoch: 1 model: 0 loss 1.3132
# Epoch: 1 model: 1 loss 1.31299
# Sz step finished
# Epoch: 2 model: 0 loss 1.27574
# Epoch: 2 model: 1 loss 1.27553
# Sz step finished
# Epoch: 3 model: 0 loss 1.24909
# Epoch: 3 model: 1 loss 1.24893
# Sz step finished
# Epoch: 4 model: 0 loss 1.22978
# Epoch: 4 model: 1 loss 1.22975
# Sz step finished
# Epoch: 5 model: 0 loss 1.21579
# Epoch: 5 model: 1 loss 1.21583
# Sz step finished
# Epoch: 6 model: 0 loss 1.20552
# Epoch: 6 model: 1 loss 1.20559
# Sz step finished
# Epoch: 7 model: 0 loss 1.19785
# Epoch: 7 model: 1 loss 1.19794
# Sz step finished
# Epoch: 8 model: 0 loss 1.19207
# Epoch: 8 model: 1 loss 1.19212
# Sz step finished
# Epoch: 9 model: 0 loss 1.18758
# Epoch: 9 model: 1 loss 1.18768
# Sz step finished
# Epoch: 10 model: 0 loss 1.18403
# Epoch: 10 model: 1 loss 1.18414
# Sz step finished
# Epoch: 11 model: 0 loss 1.1811
# Epoch: 11 model: 1 loss 1.18124
# Sz step finished
# Epoch: 12 model: 0 loss 1.17862
# Epoch: 12 model: 1 loss 1.17878
# Sz step finished
# Epoch: 13 model: 0 loss 1.1765
# Epoch: 13 model: 1 loss 1.17665
# Sz step finished
# Epoch: 14 model: 0 loss 1.17457
# Epoch: 14 model: 1 loss 1.17471
# Sz step finished
# Epoch: 15 model: 0 loss 1.17274
# Epoch: 15 model: 1 loss 1.17288
# Sz step finished
# Epoch: 16 model: 0 loss 1.171
# Epoch: 16 model: 1 loss 1.17115
# Sz step finished
# Epoch: 17 model: 0 loss 1.16928
# Epoch: 17 model: 1 loss 1.16946
# Sz step finished
# Epoch: 18 model: 0 loss 1.16752
# Epoch: 18 model: 1 loss 1.16774
# Sz step finished
# Epoch: 19 model: 0 loss 1.16573
# Epoch: 19 model: 1 loss 1.16599
# Sz step finished
# Epoch: 20 model: 0 loss 1.16385
# Epoch: 20 model: 1 loss 1.16412
# Sz step finished
# Epoch: 21 model: 0 loss 1.1619
# Epoch: 21 model: 1 loss 1.16215
# Sz step finished
# Epoch: 22 model: 0 loss 1.15982
# Epoch: 22 model: 1 loss 1.16005
# Sz step finished
# Epoch: 23 model: 0 loss 1.15759
# Epoch: 23 model: 1 loss 1.15782
# Sz step finished
# Epoch: 24 model: 0 loss 1.15522
# Epoch: 24 model: 1 loss 1.15544
# Sz step finished
# Epoch: 25 model: 0 loss 1.1527
# Epoch: 25 model: 1 loss 1.15292
# Sz step finished
# Epoch: 26 model: 0 loss 1.14998
# Epoch: 26 model: 1 loss 1.15022
# Sz step finished
# Epoch: 27 model: 0 loss 1.14709
# Epoch: 27 model: 1 loss 1.14734
# Sz step finished
# Epoch: 28 model: 0 loss 1.14398
# Epoch: 28 model: 1 loss 1.14429
# Sz step finished
# Epoch: 29 model: 0 loss 1.14067
# Epoch: 29 model: 1 loss 1.14101
# Sz step finished
# Epoch: 30 model: 0 loss 1.13716
# Epoch: 30 model: 1 loss 1.13752
# Sz step finished
# Epoch: 31 model: 0 loss 1.13343
# Epoch: 31 model: 1 loss 1.13381
# Sz step finished
# Epoch: 32 model: 0 loss 1.12947
# Epoch: 32 model: 1 loss 1.12988
# Sz step finished
# Epoch: 33 model: 0 loss 1.12538
# Epoch: 33 model: 1 loss 1.12567
# Sz step finished
# Epoch: 34 model: 0 loss 1.12105
# Epoch: 34 model: 1 loss 1.12131
# Sz step finished
# Epoch: 35 model: 0 loss 1.11647
# Epoch: 35 model: 1 loss 1.11672
# Sz step finished
# Epoch: 36 model: 0 loss 1.11171
# Epoch: 36 model: 1 loss 1.11195
# Sz step finished
# Epoch: 37 model: 0 loss 1.10669
# Epoch: 37 model: 1 loss 1.10693
# Sz step finished
# Epoch: 38 model: 0 loss 1.10156
# Epoch: 38 model: 1 loss 1.10176
# Sz step finished
# Epoch: 39 model: 0 loss 1.09631
# Epoch: 39 model: 1 loss 1.09645
# Sz step finished
# Epoch: 40 model: 0 loss 1.09085
# Epoch: 40 model: 1 loss 1.09104
# Sz step finished
# Epoch: 41 model: 0 loss 1.08535
# Epoch: 41 model: 1 loss 1.08553
# Sz step finished
# Epoch: 42 model: 0 loss 1.07977
# Epoch: 42 model: 1 loss 1.07985
# Sz step finished
# Epoch: 43 model: 0 loss 1.07401
# Epoch: 43 model: 1 loss 1.0741
# Sz step finished
# Epoch: 44 model: 0 loss 1.0682
# Epoch: 44 model: 1 loss 1.06831
# Sz step finished
# Epoch: 45 model: 0 loss 1.06243
# Epoch: 45 model: 1 loss 1.06246
# Sz step finished
# Epoch: 46 model: 0 loss 1.05661
# Epoch: 46 model: 1 loss 1.05657
# Sz step finished
# Epoch: 47 model: 0 loss 1.05068
# Epoch: 47 model: 1 loss 1.05063
# Sz step finished
# Epoch: 48 model: 0 loss 1.04478
# Epoch: 48 model: 1 loss 1.04464
# Sz step finished
# Epoch: 49 model: 0 loss 1.03873
# Epoch: 49 model: 1 loss 1.03863
# Sz step finished
# Epoch: 50 model: 0 loss 1.03259
# Epoch: 50 model: 1 loss 1.03256
# Sz step finished
# Epoch: 51 model: 0 loss 1.02639
# Epoch: 51 model: 1 loss 1.02637
# Sz step finished
# Epoch: 52 model: 0 loss 1.02013
# Epoch: 52 model: 1 loss 1.02012
# Sz step finished
# Epoch: 53 model: 0 loss 1.01377
# Epoch: 53 model: 1 loss 1.01378
# Sz step finished
# Epoch: 54 model: 0 loss 1.00735
# Epoch: 54 model: 1 loss 1.00732
# Sz step finished
# Epoch: 55 model: 0 loss 1.00073
# Epoch: 55 model: 1 loss 1.0007
# Sz step finished
# Epoch: 56 model: 0 loss 0.994034
# Epoch: 56 model: 1 loss 0.993939
# Sz step finished
# Epoch: 57 model: 0 loss 0.987088
# Epoch: 57 model: 1 loss 0.987022
# Sz step finished
# Epoch: 58 model: 0 loss 0.97999
# Epoch: 58 model: 1 loss 0.979921
# Sz step finished
# Epoch: 59 model: 0 loss 0.972776
# Epoch: 59 model: 1 loss 0.972646
# Sz step finished
# Epoch: 60 model: 0 loss 0.965272
# Epoch: 60 model: 1 loss 0.965101
# Sz step finished
# Epoch: 61 model: 0 loss 0.957509
# Epoch: 61 model: 1 loss 0.957293
# Sz step finished
# Epoch: 62 model: 0 loss 0.949414
# Epoch: 62 model: 1 loss 0.949027
# Sz step finished
# Epoch: 63 model: 0 loss 0.940951
# Epoch: 63 model: 1 loss 0.940486
# Sz step finished
# Epoch: 64 model: 0 loss 0.932104
# Epoch: 64 model: 1 loss 0.931537
# Sz step finished
# Epoch: 65 model: 0 loss 0.922893
# Epoch: 65 model: 1 loss 0.922255
# Sz step finished
# Epoch: 66 model: 0 loss 0.913222
# Epoch: 66 model: 1 loss 0.912599
# Sz step finished
# Epoch: 67 model: 0 loss 0.903291
# Epoch: 67 model: 1 loss 0.902661
# Sz step finished
# Epoch: 68 model: 0 loss 0.893029
# Epoch: 68 model: 1 loss 0.892472
# Sz step finished
# Epoch: 69 model: 0 loss 0.882441
# Epoch: 69 model: 1 loss 0.88183
# Sz step finished
# Epoch: 70 model: 0 loss 0.871354
# Epoch: 70 model: 1 loss 0.870701
# Sz step finished
# Epoch: 71 model: 0 loss 0.860116
# Epoch: 71 model: 1 loss 0.859469
# Sz step finished
# Epoch: 72 model: 0 loss 0.848718
# Epoch: 72 model: 1 loss 0.84817
# Sz step finished
# Epoch: 73 model: 0 loss 0.837167
# Epoch: 73 model: 1 loss 0.836708
# Sz step finished
# Epoch: 74 model: 0 loss 0.825529
# Epoch: 74 model: 1 loss 0.825092
# Sz step finished
# Epoch: 75 model: 0 loss 0.813616
# Epoch: 75 model: 1 loss 0.81334
# Sz step finished
# Epoch: 76 model: 0 loss 0.801776
# Epoch: 76 model: 1 loss 0.801575
# Sz step finished
# Epoch: 77 model: 0 loss 0.790065
# Epoch: 77 model: 1 loss 0.789896
# Sz step finished
# Epoch: 78 model: 0 loss 0.778387
# Epoch: 78 model: 1 loss 0.778302
# Sz step finished
# Epoch: 79 model: 0 loss 0.766852
# Epoch: 79 model: 1 loss 0.766761
# Sz step finished
# Epoch: 80 model: 0 loss 0.755426
# Epoch: 80 model: 1 loss 0.755382
# Sz step finished
# Epoch: 81 model: 0 loss 0.743933
# Epoch: 81 model: 1 loss 0.744058
# Sz step finished
# Epoch: 82 model: 0 loss 0.73262
# Epoch: 82 model: 1 loss 0.73301
# Sz step finished
# Epoch: 83 model: 0 loss 0.721607
# Epoch: 83 model: 1 loss 0.722087
# Sz step finished
# Epoch: 84 model: 0 loss 0.710358
# Epoch: 84 model: 1 loss 0.711115
# Sz step finished
# Epoch: 85 model: 0 loss 0.699402
# Epoch: 85 model: 1 loss 0.700348
# Sz step finished
# Epoch: 86 model: 0 loss 0.688852
# Epoch: 86 model: 1 loss 0.689792
# Sz step finished
# Epoch: 87 model: 0 loss 0.67826
# Epoch: 87 model: 1 loss 0.67935
# Sz step finished
# Epoch: 88 model: 0 loss 0.66771
# Epoch: 88 model: 1 loss 0.669044
# Sz step finished
# Epoch: 89 model: 0 loss 0.657013
# Epoch: 89 model: 1 loss 0.658642
# Sz step finished
# Epoch: 90 model: 0 loss 0.646383
# Epoch: 90 model: 1 loss 0.648035
# Sz step finished
# Epoch: 91 model: 0 loss 0.635818
# Epoch: 91 model: 1 loss 0.637493
# Sz step finished
# Epoch: 92 model: 0 loss 0.625057
# Epoch: 92 model: 1 loss 0.62689
# Sz step finished
# Epoch: 93 model: 0 loss 0.614399
# Epoch: 93 model: 1 loss 0.616266
# Sz step finished
# Epoch: 94 model: 0 loss 0.603741
# Epoch: 94 model: 1 loss 0.605826
# Sz step finished
# Epoch: 95 model: 0 loss 0.59292
# Epoch: 95 model: 1 loss 0.595034
# Sz step finished
# Epoch: 96 model: 0 loss 0.582397
# Epoch: 96 model: 1 loss 0.584527
# Sz step finished
# Epoch: 97 model: 0 loss 0.571868
# Epoch: 97 model: 1 loss 0.574008
# Sz step finished
# Epoch: 98 model: 0 loss 0.561659
# Epoch: 98 model: 1 loss 0.563565
# Sz step finished
# Epoch: 99 model: 0 loss 0.55145
# Epoch: 99 model: 1 loss 0.553385
# Sz step finished
# Epoch: 100 model: 0 loss 0.541398
# Epoch: 100 model: 1 loss 0.543219
# Sz step finished
# Epoch: 101 model: 0 loss 0.531399
# Epoch: 101 model: 1 loss 0.533241
# Sz step finished
# Epoch: 102 model: 0 loss 0.521111
# Epoch: 102 model: 1 loss 0.522978
# Sz step finished
# Epoch: 103 model: 0 loss 0.510453
# Epoch: 103 model: 1 loss 0.512319
# Sz step finished
# Epoch: 104 model: 0 loss 0.499319
# Epoch: 104 model: 1 loss 0.501126
# Sz step finished
# Epoch: 105 model: 0 loss 0.487617
# Epoch: 105 model: 1 loss 0.489434
# Sz step finished
# Epoch: 106 model: 0 loss 0.475834
# Epoch: 106 model: 1 loss 0.477608
# Sz step finished
# Epoch: 107 model: 0 loss 0.463686
# Epoch: 107 model: 1 loss 0.465486
# Sz step finished
# Epoch: 108 model: 0 loss 0.450972
# Epoch: 108 model: 1 loss 0.452696
# Sz step finished
# Epoch: 109 model: 0 loss 0.438339
# Epoch: 109 model: 1 loss 0.439938
# Sz step finished
# Epoch: 110 model: 0 loss 0.426016
# Epoch: 110 model: 1 loss 0.427586
# Sz step finished
# Epoch: 111 model: 0 loss 0.413792
# Epoch: 111 model: 1 loss 0.415299
# Sz step finished
# Epoch: 112 model: 0 loss 0.401411
# Epoch: 112 model: 1 loss 0.40285
# Sz step finished
# Epoch: 113 model: 0 loss 0.38817
# Epoch: 113 model: 1 loss 0.389609
# Sz step finished
# Epoch: 114 model: 0 loss 0.373674
# Epoch: 114 model: 1 loss 0.37515
# Sz step finished
# Epoch: 115 model: 0 loss 0.35679
# Epoch: 115 model: 1 loss 0.35851
# Sz step finished
# Epoch: 116 model: 0 loss 0.335636
# Epoch: 116 model: 1 loss 0.337946
# Sz step finished
# Epoch: 117 model: 0 loss 0.313293
# Epoch: 117 model: 1 loss 0.315417
# Sz step finished
# Epoch: 118 model: 0 loss 0.293928
# Epoch: 118 model: 1 loss 0.295799
# Sz step finished
# Epoch: 119 model: 0 loss 0.277204
# Epoch: 119 model: 1 loss 0.278721
# Sz step finished
# Epoch: 120 model: 0 loss 0.262671
# Epoch: 120 model: 1 loss 0.26411
# Sz step finished
# Epoch: 121 model: 0 loss 0.250116
# Epoch: 121 model: 1 loss 0.251354
# Sz step finished
# Epoch: 122 model: 0 loss 0.239018
# Epoch: 122 model: 1 loss 0.240062
# Sz step finished
# Epoch: 123 model: 0 loss 0.228919
# Epoch: 123 model: 1 loss 0.229941
# Sz step finished
# Epoch: 124 model: 0 loss 0.219616
# Epoch: 124 model: 1 loss 0.220737
# Sz step finished
# Epoch: 125 model: 0 loss 0.211274
# Epoch: 125 model: 1 loss 0.212379
# Sz step finished
# Epoch: 126 model: 0 loss 0.203751
# Epoch: 126 model: 1 loss 0.204756
# Sz step finished
# Epoch: 127 model: 0 loss 0.1968
# Epoch: 127 model: 1 loss 0.197723
# Sz step finished
# Epoch: 128 model: 0 loss 0.190442
# Epoch: 128 model: 1 loss 0.191316
# Sz step finished
# Epoch: 129 model: 0 loss 0.184553
# Epoch: 129 model: 1 loss 0.185312
# Sz step finished
# Epoch: 130 model: 0 loss 0.179101
# Epoch: 130 model: 1 loss 0.179748
# Sz step finished
# Epoch: 131 model: 0 loss 0.173979
# Epoch: 131 model: 1 loss 0.174553
# Sz step finished
# Epoch: 132 model: 0 loss 0.169217
# Epoch: 132 model: 1 loss 0.16977
# Sz step finished
# Epoch: 133 model: 0 loss 0.164642
# Epoch: 133 model: 1 loss 0.165266
# Sz step finished
# Epoch: 134 model: 0 loss 0.160386
# Epoch: 134 model: 1 loss 0.16097
# Sz step finished
# Epoch: 135 model: 0 loss 0.156403
# Epoch: 135 model: 1 loss 0.156934
# Sz step finished
# Epoch: 136 model: 0 loss 0.15258
# Epoch: 136 model: 1 loss 0.153083
# Sz step finished
# Epoch: 137 model: 0 loss 0.148954
# Epoch: 137 model: 1 loss 0.149474
# Sz step finished
# Epoch: 138 model: 0 loss 0.145468
# Epoch: 138 model: 1 loss 0.145982
# Sz step finished
# Epoch: 139 model: 0 loss 0.142205
# Epoch: 139 model: 1 loss 0.14267
# Sz step finished
# Epoch: 140 model: 0 loss 0.139027
# Epoch: 140 model: 1 loss 0.139517
# Sz step finished
# Epoch: 141 model: 0 loss 0.136061
# Epoch: 141 model: 1 loss 0.136477
# Sz step finished
# Epoch: 142 model: 0 loss 0.133168
# Epoch: 142 model: 1 loss 0.133596
# Sz step finished
# Epoch: 143 model: 0 loss 0.130452
# Epoch: 143 model: 1 loss 0.130822
# Sz step finished
# Epoch: 144 model: 0 loss 0.127807
# Epoch: 144 model: 1 loss 0.128194
# Sz step finished
# Epoch: 145 model: 0 loss 0.125266
# Epoch: 145 model: 1 loss 0.125647
# Sz step finished
# Epoch: 146 model: 0 loss 0.12281
# Epoch: 146 model: 1 loss 0.123212
# Sz step finished
# Epoch: 147 model: 0 loss 0.120472
# Epoch: 147 model: 1 loss 0.120813
# Sz step finished
# Epoch: 148 model: 0 loss 0.118196
# Epoch: 148 model: 1 loss 0.11856
# Sz step finished
# Epoch: 149 model: 0 loss 0.115998
# Epoch: 149 model: 1 loss 0.116369
# Sz step finished
# Epoch: 150 model: 0 loss 0.113902
# Epoch: 150 model: 1 loss 0.114229
# Sz step finished
# Epoch: 151 model: 0 loss 0.111835
# Epoch: 151 model: 1 loss 0.112176
# Sz step finished
# Epoch: 152 model: 0 loss 0.109835
# Epoch: 152 model: 1 loss 0.110193
# Sz step finished
# Epoch: 153 model: 0 loss 0.10795
# Epoch: 153 model: 1 loss 0.108256
# Sz step finished
# Epoch: 154 model: 0 loss 0.106076
# Epoch: 154 model: 1 loss 0.106406
# Sz step finished
# Epoch: 155 model: 0 loss 0.104294
# Epoch: 155 model: 1 loss 0.10463
# Sz step finished
# Epoch: 156 model: 0 loss 0.102559
# Epoch: 156 model: 1 loss 0.102898
# Sz step finished
# Epoch: 157 model: 0 loss 0.10087
# Epoch: 157 model: 1 loss 0.101204
# Sz step finished
# Epoch: 158 model: 0 loss 0.0992451
# Epoch: 158 model: 1 loss 0.0995835
# Sz step finished
# Epoch: 159 model: 0 loss 0.0976479
# Epoch: 159 model: 1 loss 0.0979902
# Sz step finished
# Epoch: 160 model: 0 loss 0.0960841
# Epoch: 160 model: 1 loss 0.0964125
# Sz step finished
# Epoch: 161 model: 0 loss 0.0945959
# Epoch: 161 model: 1 loss 0.0949006
# Sz step finished
# Epoch: 162 model: 0 loss 0.0931055
# Epoch: 162 model: 1 loss 0.0934519
# Sz step finished
# Epoch: 163 model: 0 loss 0.0917151
# Epoch: 163 model: 1 loss 0.092052
# Sz step finished
# Epoch: 164 model: 0 loss 0.0903435
# Epoch: 164 model: 1 loss 0.0906906
# Sz step finished
# Epoch: 165 model: 0 loss 0.0890371
# Epoch: 165 model: 1 loss 0.0893624
# Sz step finished
# Epoch: 166 model: 0 loss 0.0877333
# Epoch: 166 model: 1 loss 0.0880135
# Sz step finished
# Epoch: 167 model: 0 loss 0.0864845
# Epoch: 167 model: 1 loss 0.0867485
# Sz step finished
# Epoch: 168 model: 0 loss 0.085264
# Epoch: 168 model: 1 loss 0.0854885
# Sz step finished
# Epoch: 169 model: 0 loss 0.0840616
# Epoch: 169 model: 1 loss 0.0843037
# Sz step finished
# Epoch: 170 model: 0 loss 0.0828939
# Epoch: 170 model: 1 loss 0.0831334
# Sz step finished
# Epoch: 171 model: 0 loss 0.0817854
# Epoch: 171 model: 1 loss 0.081973
# Sz step finished
# Epoch: 172 model: 0 loss 0.0806878
# Epoch: 172 model: 1 loss 0.0808871
# Sz step finished
# Epoch: 173 model: 0 loss 0.0795937
# Epoch: 173 model: 1 loss 0.079814
# Sz step finished
# Epoch: 174 model: 0 loss 0.0785475
# Epoch: 174 model: 1 loss 0.0787392
# Sz step finished
# Epoch: 175 model: 0 loss 0.0775241
# Epoch: 175 model: 1 loss 0.0776933
# Sz step finished
# Epoch: 176 model: 0 loss 0.0765427
# Epoch: 176 model: 1 loss 0.0766917
# Sz step finished
# Epoch: 177 model: 0 loss 0.0755717
# Epoch: 177 model: 1 loss 0.0757356
# Sz step finished
# Epoch: 178 model: 0 loss 0.0746011
# Epoch: 178 model: 1 loss 0.0747572
# Sz step finished
# Epoch: 179 model: 0 loss 0.0736603
# Epoch: 179 model: 1 loss 0.0738055
# Sz step finished
# Epoch: 180 model: 0 loss 0.0727658
# Epoch: 180 model: 1 loss 0.0728812
# Sz step finished
# Epoch: 181 model: 0 loss 0.0718732
# Epoch: 181 model: 1 loss 0.0719907
# Sz step finished
# Epoch: 182 model: 0 loss 0.0709966
# Epoch: 182 model: 1 loss 0.0711168
# Sz step finished
# Epoch: 183 model: 0 loss 0.070142
# Epoch: 183 model: 1 loss 0.0702408
# Sz step finished
# Epoch: 184 model: 0 loss 0.0693043
# Epoch: 184 model: 1 loss 0.0693816
# Sz step finished
# Epoch: 185 model: 0 loss 0.0685113
# Epoch: 185 model: 1 loss 0.0685963
# Sz step finished
# Epoch: 186 model: 0 loss 0.0677192
# Epoch: 186 model: 1 loss 0.0677977
# Sz step finished
# Epoch: 187 model: 0 loss 0.0669358
# Epoch: 187 model: 1 loss 0.0670181
# Sz step finished
# Epoch: 188 model: 0 loss 0.0661733
# Epoch: 188 model: 1 loss 0.066234
# Sz step finished
# Epoch: 189 model: 0 loss 0.0654167
# Epoch: 189 model: 1 loss 0.0655131
# Sz step finished
# Epoch: 190 model: 0 loss 0.0646808
# Epoch: 190 model: 1 loss 0.0647793
# Sz step finished
# Epoch: 191 model: 0 loss 0.063961
# Epoch: 191 model: 1 loss 0.0640812
# Sz step finished
# Epoch: 192 model: 0 loss 0.0632413
# Epoch: 192 model: 1 loss 0.063367
# Sz step finished
# Epoch: 193 model: 0 loss 0.0625658
# Epoch: 193 model: 1 loss 0.062696
# Sz step finished
# Epoch: 194 model: 0 loss 0.0618846
# Epoch: 194 model: 1 loss 0.0620108
# Sz step finished
# Epoch: 195 model: 0 loss 0.0612337
# Epoch: 195 model: 1 loss 0.0613527
# Sz step finished
# Epoch: 196 model: 0 loss 0.0605979
# Epoch: 196 model: 1 loss 0.060705
# Sz step finished
# Epoch: 197 model: 0 loss 0.0599573
# Epoch: 197 model: 1 loss 0.0600662
# Sz step finished
# Epoch: 198 model: 0 loss 0.059324
# Epoch: 198 model: 1 loss 0.059442
# Sz step finished
# Epoch: 199 model: 0 loss 0.0587152
# Epoch: 199 model: 1 loss 0.0588435
# Sz step finished
# Epoch: 200 model: 0 loss 0.0580973
# Epoch: 200 model: 1 loss 0.0582611
# Sz step finished
# Epoch: 201 model: 0 loss 0.0575042
# Epoch: 201 model: 1 loss 0.0576615
# Sz step finished
# Epoch: 202 model: 0 loss 0.0569158
# Epoch: 202 model: 1 loss 0.057089
# Sz step finished
# Epoch: 203 model: 0 loss 0.0563463
# Epoch: 203 model: 1 loss 0.0565288
# Sz step finished
# Epoch: 204 model: 0 loss 0.0558026
# Epoch: 204 model: 1 loss 0.0559762
# Sz step finished
# Epoch: 205 model: 0 loss 0.0552486
# Epoch: 205 model: 1 loss 0.0554418
# Sz step finished
# Epoch: 206 model: 0 loss 0.0547111
# Epoch: 206 model: 1 loss 0.0549063
# Sz step finished
# Epoch: 207 model: 0 loss 0.054197
# Epoch: 207 model: 1 loss 0.05439
# Sz step finished
# Epoch: 208 model: 0 loss 0.0536805
# Epoch: 208 model: 1 loss 0.0538595
# Sz step finished
# Epoch: 209 model: 0 loss 0.0531688
# Epoch: 209 model: 1 loss 0.0533727
# Sz step finished
# Epoch: 210 model: 0 loss 0.0526786
# Epoch: 210 model: 1 loss 0.0528855
# Sz step finished
# Epoch: 211 model: 0 loss 0.0521818
# Epoch: 211 model: 1 loss 0.0523853
# Sz step finished
# Epoch: 212 model: 0 loss 0.0517126
# Epoch: 212 model: 1 loss 0.0519166
# Sz step finished
# Epoch: 213 model: 0 loss 0.0512408
# Epoch: 213 model: 1 loss 0.0514386
# Sz step finished
# Epoch: 214 model: 0 loss 0.0507837
# Epoch: 214 model: 1 loss 0.0509844
# Sz step finished
# Epoch: 215 model: 0 loss 0.0503236
# Epoch: 215 model: 1 loss 0.0505295
# Sz step finished
# Epoch: 216 model: 0 loss 0.0498688
# Epoch: 216 model: 1 loss 0.0500749
# Sz step finished
# Epoch: 217 model: 0 loss 0.0494138
# Epoch: 217 model: 1 loss 0.0496162
# Sz step finished
# Epoch: 218 model: 0 loss 0.0489697
# Epoch: 218 model: 1 loss 0.0491816
# Sz step finished
# Epoch: 219 model: 0 loss 0.0485484
# Epoch: 219 model: 1 loss 0.048742
# Sz step finished
# Epoch: 220 model: 0 loss 0.0481413
# Epoch: 220 model: 1 loss 0.0483056
# Sz step finished
# Epoch: 221 model: 0 loss 0.0477012
# Epoch: 221 model: 1 loss 0.0478834
# Sz step finished
# Epoch: 222 model: 0 loss 0.0472936
# Epoch: 222 model: 1 loss 0.0474854
# Sz step finished
# Epoch: 223 model: 0 loss 0.0469019
# Epoch: 223 model: 1 loss 0.0470955
# Sz step finished
# Epoch: 224 model: 0 loss 0.0464885
# Epoch: 224 model: 1 loss 0.0467144
# Sz step finished
# Epoch: 225 model: 0 loss 0.0461037
# Epoch: 225 model: 1 loss 0.0463236
# Sz step finished
# Epoch: 226 model: 0 loss 0.0457176
# Epoch: 226 model: 1 loss 0.0459434
# Sz step finished
# Epoch: 227 model: 0 loss 0.0453352
# Epoch: 227 model: 1 loss 0.0455702
# Sz step finished
# Epoch: 228 model: 0 loss 0.0449686
# Epoch: 228 model: 1 loss 0.0452108
# Sz step finished
# Epoch: 229 model: 0 loss 0.0446167
# Epoch: 229 model: 1 loss 0.0448325
# Sz step finished
# Epoch: 230 model: 0 loss 0.0442548
# Epoch: 230 model: 1 loss 0.0444797
# Sz step finished
# Epoch: 231 model: 0 loss 0.0439038
# Epoch: 231 model: 1 loss 0.0441285
# Sz step finished
# Epoch: 232 model: 0 loss 0.0435602
# Epoch: 232 model: 1 loss 0.043779
# Sz step finished
# Epoch: 233 model: 0 loss 0.0432181
# Epoch: 233 model: 1 loss 0.0434359
# Sz step finished
# Epoch: 234 model: 0 loss 0.0428897
# Epoch: 234 model: 1 loss 0.0431034
# Sz step finished
# Epoch: 235 model: 0 loss 0.0425629
# Epoch: 235 model: 1 loss 0.0427661
# Sz step finished
# Epoch: 236 model: 0 loss 0.042233
# Epoch: 236 model: 1 loss 0.0424416
# Sz step finished
# Epoch: 237 model: 0 loss 0.041916
# Epoch: 237 model: 1 loss 0.0421076
# Sz step finished
# Epoch: 238 model: 0 loss 0.0416015
# Epoch: 238 model: 1 loss 0.0417856
# Sz step finished
# Epoch: 239 model: 0 loss 0.0412809
# Epoch: 239 model: 1 loss 0.041462
# Sz step finished
# Epoch: 240 model: 0 loss 0.0409735
# Epoch: 240 model: 1 loss 0.0411396
# Sz step finished
# Epoch: 241 model: 0 loss 0.0406615
# Epoch: 241 model: 1 loss 0.0408368
# Sz step finished
# Epoch: 242 model: 0 loss 0.0403517
# Epoch: 242 model: 1 loss 0.04054
# Sz step finished
# Epoch: 243 model: 0 loss 0.0400474
# Epoch: 243 model: 1 loss 0.0402547
# Sz step finished
# Epoch: 244 model: 0 loss 0.0397543
# Epoch: 244 model: 1 loss 0.0399686
# Sz step finished
# Epoch: 245 model: 0 loss 0.0394678
# Epoch: 245 model: 1 loss 0.0396803
# Sz step finished
# Epoch: 246 model: 0 loss 0.0391865
# Epoch: 246 model: 1 loss 0.0393892
# Sz step finished
# Epoch: 247 model: 0 loss 0.0389182
# Epoch: 247 model: 1 loss 0.0391075
# Sz step finished
# Epoch: 248 model: 0 loss 0.0386447
# Epoch: 248 model: 1 loss 0.0388324
# Sz step finished
# Epoch: 249 model: 0 loss 0.0383671
# Epoch: 249 model: 1 loss 0.0385641
# Sz step finished
# Epoch: 250 model: 0 loss 0.0380963
# Epoch: 250 model: 1 loss 0.0382923
# Sz step finished
# Epoch: 251 model: 0 loss 0.0378232
# Epoch: 251 model: 1 loss 0.0380283
# Sz step finished
# Epoch: 252 model: 0 loss 0.0375561
# Epoch: 252 model: 1 loss 0.037756
# Sz step finished
# Epoch: 253 model: 0 loss 0.0372947
# Epoch: 253 model: 1 loss 0.0374956
# Sz step finished
# Epoch: 254 model: 0 loss 0.037037
# Epoch: 254 model: 1 loss 0.037233
# Sz step finished
# Epoch: 255 model: 0 loss 0.0367929
# Epoch: 255 model: 1 loss 0.036989
# Sz step finished
# Epoch: 256 model: 0 loss 0.0365429
# Epoch: 256 model: 1 loss 0.0367347
# Sz step finished
# Epoch: 257 model: 0 loss 0.0363035
# Epoch: 257 model: 1 loss 0.036488
# Sz step finished
# Epoch: 258 model: 0 loss 0.0360607
# Epoch: 258 model: 1 loss 0.0362416
# Sz step finished
# Epoch: 259 model: 0 loss 0.0358237
# Epoch: 259 model: 1 loss 0.0359938
# Sz step finished
# Epoch: 260 model: 0 loss 0.035579
# Epoch: 260 model: 1 loss 0.0357586
# Sz step finished
# Epoch: 261 model: 0 loss 0.0353438
# Epoch: 261 model: 1 loss 0.0355264
# Sz step finished
# Epoch: 262 model: 0 loss 0.0351196
# Epoch: 262 model: 1 loss 0.0352943
# Sz step finished
# Epoch: 263 model: 0 loss 0.0349007
# Epoch: 263 model: 1 loss 0.035072
# Sz step finished
# Epoch: 264 model: 0 loss 0.0346772
# Epoch: 264 model: 1 loss 0.0348374
# Sz step finished
# Epoch: 265 model: 0 loss 0.0344564
# Epoch: 265 model: 1 loss 0.0346203
# Sz step finished
# Epoch: 266 model: 0 loss 0.0342358
# Epoch: 266 model: 1 loss 0.0344139
# Sz step finished
# Epoch: 267 model: 0 loss 0.0340191
# Epoch: 267 model: 1 loss 0.0341844
# Sz step finished
# Epoch: 268 model: 0 loss 0.0338044
# Epoch: 268 model: 1 loss 0.033969
# Sz step finished
# Epoch: 269 model: 0 loss 0.0335871
# Epoch: 269 model: 1 loss 0.0337627
# Sz step finished
# Epoch: 270 model: 0 loss 0.0333714
# Epoch: 270 model: 1 loss 0.0335545
# Sz step finished
# Epoch: 271 model: 0 loss 0.0331686
# Epoch: 271 model: 1 loss 0.0333375
# Sz step finished
# Epoch: 272 model: 0 loss 0.0329599
# Epoch: 272 model: 1 loss 0.0331267
# Sz step finished
# Epoch: 273 model: 0 loss 0.0327572
# Epoch: 273 model: 1 loss 0.0329209
# Sz step finished
# Epoch: 274 model: 0 loss 0.0325623
# Epoch: 274 model: 1 loss 0.0327308
# Sz step finished
# Epoch: 275 model: 0 loss 0.0323703
# Epoch: 275 model: 1 loss 0.0325387
# Sz step finished
# Epoch: 276 model: 0 loss 0.0321747
# Epoch: 276 model: 1 loss 0.0323361
# Sz step finished
# Epoch: 277 model: 0 loss 0.0319867
# Epoch: 277 model: 1 loss 0.0321416
# Sz step finished
# Epoch: 278 model: 0 loss 0.0317955
# Epoch: 278 model: 1 loss 0.0319353
# Sz step finished
# Epoch: 279 model: 0 loss 0.0316028
# Epoch: 279 model: 1 loss 0.0317443
# Sz step finished
# Epoch: 280 model: 0 loss 0.0314265
# Epoch: 280 model: 1 loss 0.0315748
# Sz step finished
# Epoch: 281 model: 0 loss 0.031236
# Epoch: 281 model: 1 loss 0.0313843
# Sz step finished
# Epoch: 282 model: 0 loss 0.0310513
# Epoch: 282 model: 1 loss 0.0312066
# Sz step finished
# Epoch: 283 model: 0 loss 0.0308719
# Epoch: 283 model: 1 loss 0.0310318
# Sz step finished
# Epoch: 284 model: 0 loss 0.0306999
# Epoch: 284 model: 1 loss 0.0308538
# Sz step finished
# Epoch: 285 model: 0 loss 0.0305311
# Epoch: 285 model: 1 loss 0.0306759
# Sz step finished
# Epoch: 286 model: 0 loss 0.0303416
# Epoch: 286 model: 1 loss 0.0305134
# Sz step finished
# Epoch: 287 model: 0 loss 0.0301708
# Epoch: 287 model: 1 loss 0.0303451
# Sz step finished
# Epoch: 288 model: 0 loss 0.0300095
# Epoch: 288 model: 1 loss 0.030165
# Sz step finished
# Epoch: 289 model: 0 loss 0.0298332
# Epoch: 289 model: 1 loss 0.0299894
# Sz step finished
# Epoch: 290 model: 0 loss 0.0296579
# Epoch: 290 model: 1 loss 0.029826
# Sz step finished
# Epoch: 291 model: 0 loss 0.0294918
# Epoch: 291 model: 1 loss 0.0296699
# Sz step finished
# Epoch: 292 model: 0 loss 0.0293291
# Epoch: 292 model: 1 loss 0.0295062
# Sz step finished
# Epoch: 293 model: 0 loss 0.0291695
# Epoch: 293 model: 1 loss 0.0293449
# Sz step finished
# Epoch: 294 model: 0 loss 0.0290227
# Epoch: 294 model: 1 loss 0.0291813
# Sz step finished
# Epoch: 295 model: 0 loss 0.0288702
# Epoch: 295 model: 1 loss 0.0290165
# Sz step finished
# Epoch: 296 model: 0 loss 0.0287137
# Epoch: 296 model: 1 loss 0.0288509
# Sz step finished
# Epoch: 297 model: 0 loss 0.0285496
# Epoch: 297 model: 1 loss 0.0286928
# Sz step finished
# Epoch: 298 model: 0 loss 0.0283939
# Epoch: 298 model: 1 loss 0.0285392
# Sz step finished
# Epoch: 299 model: 0 loss 0.0282448
# Epoch: 299 model: 1 loss 0.0284007
# Sz step finished
# Epoch: 300 model: 0 loss 0.0280944
# Epoch: 300 model: 1 loss 0.0282508
# Sz step finished
# Epoch: 301 model: 0 loss 0.027947
# Epoch: 301 model: 1 loss 0.0281009
# Sz step finished
# Epoch: 302 model: 0 loss 0.027798
# Epoch: 302 model: 1 loss 0.0279562
# Sz step finished
# Epoch: 303 model: 0 loss 0.0276445
# Epoch: 303 model: 1 loss 0.0278108
# Sz step finished
# Epoch: 304 model: 0 loss 0.0274951
# Epoch: 304 model: 1 loss 0.0276743
# Sz step finished
# Epoch: 305 model: 0 loss 0.0273532
# Epoch: 305 model: 1 loss 0.0275366
# Sz step finished
# Epoch: 306 model: 0 loss 0.0272105
# Epoch: 306 model: 1 loss 0.0273959
# Sz step finished
# Epoch: 307 model: 0 loss 0.0270779
# Epoch: 307 model: 1 loss 0.0272657
# Sz step finished
# Epoch: 308 model: 0 loss 0.026944
# Epoch: 308 model: 1 loss 0.0271283
# Sz step finished
# Epoch: 309 model: 0 loss 0.0267981
# Epoch: 309 model: 1 loss 0.0269927
# Sz step finished
# Epoch: 310 model: 0 loss 0.0266614
# Epoch: 310 model: 1 loss 0.0268526
# Sz step finished
# Epoch: 311 model: 0 loss 0.0265262
# Epoch: 311 model: 1 loss 0.0267185
# Sz step finished
# Epoch: 312 model: 0 loss 0.0263941
# Epoch: 312 model: 1 loss 0.0265844
# Sz step finished
# Epoch: 313 model: 0 loss 0.0262729
# Epoch: 313 model: 1 loss 0.0264472
# Sz step finished
# Epoch: 314 model: 0 loss 0.026143
# Epoch: 314 model: 1 loss 0.0263107
# Sz step finished
# Epoch: 315 model: 0 loss 0.0260104
# Epoch: 315 model: 1 loss 0.0261869
# Sz step finished
# Epoch: 316 model: 0 loss 0.0258907
# Epoch: 316 model: 1 loss 0.0260457
# Sz step finished
# Epoch: 317 model: 0 loss 0.0257622
# Epoch: 317 model: 1 loss 0.0259082
# Sz step finished
# Epoch: 318 model: 0 loss 0.0256378
# Epoch: 318 model: 1 loss 0.0257787
# Sz step finished
# Epoch: 319 model: 0 loss 0.0255185
# Epoch: 319 model: 1 loss 0.0256446
# Sz step finished
# Epoch: 320 model: 0 loss 0.0253917
# Epoch: 320 model: 1 loss 0.0255264
# Sz step finished
# Epoch: 321 model: 0 loss 0.0252596
# Epoch: 321 model: 1 loss 0.0254108
# Sz step finished
# Epoch: 322 model: 0 loss 0.0251242
# Epoch: 322 model: 1 loss 0.0252926
# Sz step finished
# Epoch: 323 model: 0 loss 0.0250028
# Epoch: 323 model: 1 loss 0.0251817
# Sz step finished
# Epoch: 324 model: 0 loss 0.0248897
# Epoch: 324 model: 1 loss 0.0250588
# Sz step finished
# Epoch: 325 model: 0 loss 0.024768
# Epoch: 325 model: 1 loss 0.0249465
# Sz step finished
# Epoch: 326 model: 0 loss 0.0246452
# Epoch: 326 model: 1 loss 0.0248292
# Sz step finished
# Epoch: 327 model: 0 loss 0.0245279
# Epoch: 327 model: 1 loss 0.0247065
# Sz step finished
# Epoch: 328 model: 0 loss 0.0244251
# Epoch: 328 model: 1 loss 0.0245816
# Sz step finished
# Epoch: 329 model: 0 loss 0.0243134
# Epoch: 329 model: 1 loss 0.024476
# Sz step finished
# Epoch: 330 model: 0 loss 0.0241997
# Epoch: 330 model: 1 loss 0.0243692
# Sz step finished
# Epoch: 331 model: 0 loss 0.0240881
# Epoch: 331 model: 1 loss 0.0242585
# Sz step finished
# Epoch: 332 model: 0 loss 0.0239835
# Epoch: 332 model: 1 loss 0.0241514
# Sz step finished
# Epoch: 333 model: 0 loss 0.0238728
# Epoch: 333 model: 1 loss 0.0240425
# Sz step finished
# Epoch: 334 model: 0 loss 0.0237641
# Epoch: 334 model: 1 loss 0.0239373
# Sz step finished
# Epoch: 335 model: 0 loss 0.0236561
# Epoch: 335 model: 1 loss 0.023821
# Sz step finished
# Epoch: 336 model: 0 loss 0.0235515
# Epoch: 336 model: 1 loss 0.0237048
# Sz step finished
# Epoch: 337 model: 0 loss 0.0234424
# Epoch: 337 model: 1 loss 0.0235996
# Sz step finished
# Epoch: 338 model: 0 loss 0.0233423
# Epoch: 338 model: 1 loss 0.0234918
# Sz step finished
# Epoch: 339 model: 0 loss 0.0232343
# Epoch: 339 model: 1 loss 0.0233769
# Sz step finished
# Epoch: 340 model: 0 loss 0.023143
# Epoch: 340 model: 1 loss 0.0232803
# Sz step finished
# Epoch: 341 model: 0 loss 0.0230394
# Epoch: 341 model: 1 loss 0.0231696
# Sz step finished
# Epoch: 342 model: 0 loss 0.0229394
# Epoch: 342 model: 1 loss 0.0230706
# Sz step finished
# Epoch: 343 model: 0 loss 0.0228378
# Epoch: 343 model: 1 loss 0.0229688
# Sz step finished
# Epoch: 344 model: 0 loss 0.0227371
# Epoch: 344 model: 1 loss 0.022861
# Sz step finished
# Epoch: 345 model: 0 loss 0.0226421
# Epoch: 345 model: 1 loss 0.0227655
# Sz step finished
# Epoch: 346 model: 0 loss 0.0225364
# Epoch: 346 model: 1 loss 0.0226646
# Sz step finished
# Epoch: 347 model: 0 loss 0.0224345
# Epoch: 347 model: 1 loss 0.0225679
# Sz step finished
# Epoch: 348 model: 0 loss 0.0223385
# Epoch: 348 model: 1 loss 0.022472
# Sz step finished
# Epoch: 349 model: 0 loss 0.0222409
# Epoch: 349 model: 1 loss 0.0223697
# Sz step finished
# Epoch: 350 model: 0 loss 0.0221424
# Epoch: 350 model: 1 loss 0.0222811
# Sz step finished
# Epoch: 351 model: 0 loss 0.0220518
# Epoch: 351 model: 1 loss 0.0221944
# Sz step finished
# Epoch: 352 model: 0 loss 0.0219622
# Epoch: 352 model: 1 loss 0.0220993
# Sz step finished
# Epoch: 353 model: 0 loss 0.0218724
# Epoch: 353 model: 1 loss 0.0220056
# Sz step finished
# Epoch: 354 model: 0 loss 0.0217816
# Epoch: 354 model: 1 loss 0.0219081
# Sz step finished
# Epoch: 355 model: 0 loss 0.0216921
# Epoch: 355 model: 1 loss 0.0218064
# Sz step finished
# Epoch: 356 model: 0 loss 0.0216012
# Epoch: 356 model: 1 loss 0.0217174
# Sz step finished
# Epoch: 357 model: 0 loss 0.0215153
# Epoch: 357 model: 1 loss 0.0216292
# Sz step finished
# Epoch: 358 model: 0 loss 0.0214291
# Epoch: 358 model: 1 loss 0.0215298
# Sz step finished
# Epoch: 359 model: 0 loss 0.0213404
# Epoch: 359 model: 1 loss 0.0214383
# Sz step finished
# Epoch: 360 model: 0 loss 0.0212471
# Epoch: 360 model: 1 loss 0.0213495
# Sz step finished
# Epoch: 361 model: 0 loss 0.0211596
# Epoch: 361 model: 1 loss 0.0212631
# Sz step finished
# Epoch: 362 model: 0 loss 0.0210744
# Epoch: 362 model: 1 loss 0.0211697
# Sz step finished
# Epoch: 363 model: 0 loss 0.0209948
# Epoch: 363 model: 1 loss 0.0210922
# Sz step finished
# Epoch: 364 model: 0 loss 0.0209111
# Epoch: 364 model: 1 loss 0.0210121
# Sz step finished
# Epoch: 365 model: 0 loss 0.0208306
# Epoch: 365 model: 1 loss 0.020923
# Sz step finished
# Epoch: 366 model: 0 loss 0.0207476
# Epoch: 366 model: 1 loss 0.020837
# Sz step finished
# Epoch: 367 model: 0 loss 0.0206626
# Epoch: 367 model: 1 loss 0.0207497
# Sz step finished
# Epoch: 368 model: 0 loss 0.020586
# Epoch: 368 model: 1 loss 0.020667
# Sz step finished
# Epoch: 369 model: 0 loss 0.0205036
# Epoch: 369 model: 1 loss 0.0205733
# Sz step finished
# Epoch: 370 model: 0 loss 0.0204211
# Epoch: 370 model: 1 loss 0.0204994
# Sz step finished
# Epoch: 371 model: 0 loss 0.0203421
# Epoch: 371 model: 1 loss 0.0204187
# Sz step finished
# Epoch: 372 model: 0 loss 0.0202639
# Epoch: 372 model: 1 loss 0.020345
# Sz step finished
# Epoch: 373 model: 0 loss 0.02017
# Epoch: 373 model: 1 loss 0.0202667
# Sz step finished
# Epoch: 374 model: 0 loss 0.0200979
# Epoch: 374 model: 1 loss 0.0201934
# Sz step finished
# Epoch: 375 model: 0 loss 0.0200129
# Epoch: 375 model: 1 loss 0.0201096
# Sz step finished
# Epoch: 376 model: 0 loss 0.0199362
# Epoch: 376 model: 1 loss 0.0200304
# Sz step finished
# Epoch: 377 model: 0 loss 0.0198631
# Epoch: 377 model: 1 loss 0.0199514
# Sz step finished
# Epoch: 378 model: 0 loss 0.0197857
# Epoch: 378 model: 1 loss 0.0198693
# Sz step finished
# Epoch: 379 model: 0 loss 0.0197053
# Epoch: 379 model: 1 loss 0.0197945
# Sz step finished
# Epoch: 380 model: 0 loss 0.0196205
# Epoch: 380 model: 1 loss 0.0197191
# Sz step finished
# Epoch: 381 model: 0 loss 0.0195473
# Epoch: 381 model: 1 loss 0.0196432
# Sz step finished
# Epoch: 382 model: 0 loss 0.0194755
# Epoch: 382 model: 1 loss 0.0195733
# Sz step finished
# Epoch: 383 model: 0 loss 0.019401
# Epoch: 383 model: 1 loss 0.0195009
# Sz step finished
# Epoch: 384 model: 0 loss 0.0193266
# Epoch: 384 model: 1 loss 0.0194361
# Sz step finished
# Epoch: 385 model: 0 loss 0.0192529
# Epoch: 385 model: 1 loss 0.0193711
# Sz step finished
# Epoch: 386 model: 0 loss 0.0191828
# Epoch: 386 model: 1 loss 0.0192939
# Sz step finished
# Epoch: 387 model: 0 loss 0.0191118
# Epoch: 387 model: 1 loss 0.0192219
# Sz step finished
# Epoch: 388 model: 0 loss 0.0190422
# Epoch: 388 model: 1 loss 0.0191489
# Sz step finished
# Epoch: 389 model: 0 loss 0.0189716
# Epoch: 389 model: 1 loss 0.019074
# Sz step finished
# Epoch: 390 model: 0 loss 0.0189051
# Epoch: 390 model: 1 loss 0.0190052
# Sz step finished
# Epoch: 391 model: 0 loss 0.0188381
# Epoch: 391 model: 1 loss 0.0189435
# Sz step finished
# Epoch: 392 model: 0 loss 0.0187632
# Epoch: 392 model: 1 loss 0.0188645
# Sz step finished
# Epoch: 393 model: 0 loss 0.018693
# Epoch: 393 model: 1 loss 0.0187991
# Sz step finished
# Epoch: 394 model: 0 loss 0.0186242
# Epoch: 394 model: 1 loss 0.0187355
# Sz step finished
# Epoch: 395 model: 0 loss 0.0185577
# Epoch: 395 model: 1 loss 0.0186744
# Sz step finished
# Epoch: 396 model: 0 loss 0.0184906
# Epoch: 396 model: 1 loss 0.0186062
# Sz step finished
# Epoch: 397 model: 0 loss 0.01842
# Epoch: 397 model: 1 loss 0.0185388
# Sz step finished
# Epoch: 398 model: 0 loss 0.0183509
# Epoch: 398 model: 1 loss 0.0184648
# Sz step finished
# Epoch: 399 model: 0 loss 0.0182848
# Epoch: 399 model: 1 loss 0.0183987
# Sz step finished
# Epoch: 400 model: 0 loss 0.018218
# Epoch: 400 model: 1 loss 0.0183316
# Sz step finished
# Epoch: 401 model: 0 loss 0.0181574
# Epoch: 401 model: 1 loss 0.0182629
# Sz step finished
# Epoch: 402 model: 0 loss 0.0180902
# Epoch: 402 model: 1 loss 0.0181903
# Sz step finished
# Epoch: 403 model: 0 loss 0.0180308
# Epoch: 403 model: 1 loss 0.0181244
# Sz step finished
# Epoch: 404 model: 0 loss 0.0179618
# Epoch: 404 model: 1 loss 0.0180603
# Sz step finished
# Epoch: 405 model: 0 loss 0.017897
# Epoch: 405 model: 1 loss 0.0179965
# Sz step finished
# Epoch: 406 model: 0 loss 0.0178325
# Epoch: 406 model: 1 loss 0.0179333
# Sz step finished
# Epoch: 407 model: 0 loss 0.017768
# Epoch: 407 model: 1 loss 0.0178733
# Sz step finished
# Epoch: 408 model: 0 loss 0.0177097
# Epoch: 408 model: 1 loss 0.0178153
# Sz step finished
# Epoch: 409 model: 0 loss 0.0176458
# Epoch: 409 model: 1 loss 0.0177573
# Sz step finished
# Epoch: 410 model: 0 loss 0.0175793
# Epoch: 410 model: 1 loss 0.017692
# Sz step finished
# Epoch: 411 model: 0 loss 0.0175165
# Epoch: 411 model: 1 loss 0.0176374
# Sz step finished
# Epoch: 412 model: 0 loss 0.0174548
# Epoch: 412 model: 1 loss 0.0175762
# Sz step finished
# Epoch: 413 model: 0 loss 0.0173982
# Epoch: 413 model: 1 loss 0.0175103
# Sz step finished
# Epoch: 414 model: 0 loss 0.0173442
# Epoch: 414 model: 1 loss 0.0174498
# Sz step finished
# Epoch: 415 model: 0 loss 0.0172888
# Epoch: 415 model: 1 loss 0.0173885
# Sz step finished
# Epoch: 416 model: 0 loss 0.0172342
# Epoch: 416 model: 1 loss 0.0173314
# Sz step finished
# Epoch: 417 model: 0 loss 0.0171798
# Epoch: 417 model: 1 loss 0.0172746
# Sz step finished
# Epoch: 418 model: 0 loss 0.0171197
# Epoch: 418 model: 1 loss 0.0172128
# Sz step finished
# Epoch: 419 model: 0 loss 0.017069
# Epoch: 419 model: 1 loss 0.0171551
# Sz step finished
# Epoch: 420 model: 0 loss 0.0170088
# Epoch: 420 model: 1 loss 0.0171015
# Sz step finished
# Epoch: 421 model: 0 loss 0.0169495
# Epoch: 421 model: 1 loss 0.0170428
# Sz step finished
# Epoch: 422 model: 0 loss 0.0168923
# Epoch: 422 model: 1 loss 0.0169873
# Sz step finished
# Epoch: 423 model: 0 loss 0.0168407
# Epoch: 423 model: 1 loss 0.0169316
# Sz step finished
# Epoch: 424 model: 0 loss 0.0167876
# Epoch: 424 model: 1 loss 0.0168786
# Sz step finished
# Epoch: 425 model: 0 loss 0.0167352
# Epoch: 425 model: 1 loss 0.0168195
# Sz step finished
# Epoch: 426 model: 0 loss 0.0166775
# Epoch: 426 model: 1 loss 0.0167643
# Sz step finished
# Epoch: 427 model: 0 loss 0.0166238
# Epoch: 427 model: 1 loss 0.0167021
# Sz step finished
# Epoch: 428 model: 0 loss 0.0165727
# Epoch: 428 model: 1 loss 0.016643
# Sz step finished
# Epoch: 429 model: 0 loss 0.0165134
# Epoch: 429 model: 1 loss 0.0165877
# Sz step finished
# Epoch: 430 model: 0 loss 0.0164574
# Epoch: 430 model: 1 loss 0.0165331
# Sz step finished
# Epoch: 431 model: 0 loss 0.0164031
# Epoch: 431 model: 1 loss 0.0164755
# Sz step finished
# Epoch: 432 model: 0 loss 0.0163472
# Epoch: 432 model: 1 loss 0.0164199
# Sz step finished
# Epoch: 433 model: 0 loss 0.0162972
# Epoch: 433 model: 1 loss 0.0163688
# Sz step finished
# Epoch: 434 model: 0 loss 0.0162465
# Epoch: 434 model: 1 loss 0.0163184
# Sz step finished
# Epoch: 435 model: 0 loss 0.016191
# Epoch: 435 model: 1 loss 0.01627
# Sz step finished
# Epoch: 436 model: 0 loss 0.0161435
# Epoch: 436 model: 1 loss 0.0162243
# Sz step finished
# Epoch: 437 model: 0 loss 0.0160923
# Epoch: 437 model: 1 loss 0.0161693
# Sz step finished
# Epoch: 438 model: 0 loss 0.0160444
# Epoch: 438 model: 1 loss 0.0161172
# Sz step finished
# Epoch: 439 model: 0 loss 0.0159953
# Epoch: 439 model: 1 loss 0.0160695
# Sz step finished
# Epoch: 440 model: 0 loss 0.0159394
# Epoch: 440 model: 1 loss 0.0160125
# Sz step finished
# Epoch: 441 model: 0 loss 0.0158922
# Epoch: 441 model: 1 loss 0.0159637
# Sz step finished
# Epoch: 442 model: 0 loss 0.0158426
# Epoch: 442 model: 1 loss 0.0159078
# Sz step finished
# Epoch: 443 model: 0 loss 0.0157921
# Epoch: 443 model: 1 loss 0.0158604
# Sz step finished
# Epoch: 444 model: 0 loss 0.0157471
# Epoch: 444 model: 1 loss 0.0158096
# Sz step finished
# Epoch: 445 model: 0 loss 0.0156993
# Epoch: 445 model: 1 loss 0.0157634
# Sz step finished
# Epoch: 446 model: 0 loss 0.0156486
# Epoch: 446 model: 1 loss 0.0157177
# Sz step finished
# Epoch: 447 model: 0 loss 0.0156023
# Epoch: 447 model: 1 loss 0.0156674
# Sz step finished
# Epoch: 448 model: 0 loss 0.015551
# Epoch: 448 model: 1 loss 0.0156208
# Sz step finished
# Epoch: 449 model: 0 loss 0.0154981
# Epoch: 449 model: 1 loss 0.0155732
# Sz step finished
# Epoch: 450 model: 0 loss 0.0154453
# Epoch: 450 model: 1 loss 0.0155256
# Sz step finished
# Epoch: 451 model: 0 loss 0.015398
# Epoch: 451 model: 1 loss 0.0154771
# Sz step finished
# Epoch: 452 model: 0 loss 0.0153471
# Epoch: 452 model: 1 loss 0.0154277
# Sz step finished
# Epoch: 453 model: 0 loss 0.0153023
# Epoch: 453 model: 1 loss 0.0153816
# Sz step finished
# Epoch: 454 model: 0 loss 0.0152573
# Epoch: 454 model: 1 loss 0.015337
# Sz step finished
# Epoch: 455 model: 0 loss 0.01521
# Epoch: 455 model: 1 loss 0.0152924
# Sz step finished
# Epoch: 456 model: 0 loss 0.0151597
# Epoch: 456 model: 1 loss 0.0152489
# Sz step finished
# Epoch: 457 model: 0 loss 0.0151171
# Epoch: 457 model: 1 loss 0.0152062
# Sz step finished
# Epoch: 458 model: 0 loss 0.0150745
# Epoch: 458 model: 1 loss 0.0151593
# Sz step finished
# Epoch: 459 model: 0 loss 0.0150326
# Epoch: 459 model: 1 loss 0.0151183
# Sz step finished
# Epoch: 460 model: 0 loss 0.0149918
# Epoch: 460 model: 1 loss 0.0150785
# Sz step finished
# Epoch: 461 model: 0 loss 0.0149495
# Epoch: 461 model: 1 loss 0.0150344
# Sz step finished
# Epoch: 462 model: 0 loss 0.0149039
# Epoch: 462 model: 1 loss 0.0149891
# Sz step finished
# Epoch: 463 model: 0 loss 0.014855
# Epoch: 463 model: 1 loss 0.0149434
# Sz step finished
# Epoch: 464 model: 0 loss 0.0148134
# Epoch: 464 model: 1 loss 0.0148986
# Sz step finished
# Epoch: 465 model: 0 loss 0.0147679
# Epoch: 465 model: 1 loss 0.0148616
# Sz step finished
# Epoch: 466 model: 0 loss 0.0147259
# Epoch: 466 model: 1 loss 0.0148186
# Sz step finished
# Epoch: 467 model: 0 loss 0.014684
# Epoch: 467 model: 1 loss 0.0147727
# Sz step finished
# Epoch: 468 model: 0 loss 0.0146405
# Epoch: 468 model: 1 loss 0.0147305
# Sz step finished
# Epoch: 469 model: 0 loss 0.0145984
# Epoch: 469 model: 1 loss 0.0146839
# Sz step finished
# Epoch: 470 model: 0 loss 0.0145531
# Epoch: 470 model: 1 loss 0.0146375
# Sz step finished
# Epoch: 471 model: 0 loss 0.0145103
# Epoch: 471 model: 1 loss 0.0145939
# Sz step finished
# Epoch: 472 model: 0 loss 0.0144644
# Epoch: 472 model: 1 loss 0.0145533
# Sz step finished
# Epoch: 473 model: 0 loss 0.0144229
# Epoch: 473 model: 1 loss 0.014511
# Sz step finished
# Epoch: 474 model: 0 loss 0.0143873
# Epoch: 474 model: 1 loss 0.0144692
# Sz step finished
# Epoch: 475 model: 0 loss 0.0143486
# Epoch: 475 model: 1 loss 0.0144284
# Sz step finished
# Epoch: 476 model: 0 loss 0.0143075
# Epoch: 476 model: 1 loss 0.0143896
# Sz step finished
# Epoch: 477 model: 0 loss 0.0142666
# Epoch: 477 model: 1 loss 0.0143458
# Sz step finished
# Epoch: 478 model: 0 loss 0.0142284
# Epoch: 478 model: 1 loss 0.0143027
# Sz step finished
# Epoch: 479 model: 0 loss 0.0141926
# Epoch: 479 model: 1 loss 0.0142591
# Sz step finished
# Epoch: 480 model: 0 loss 0.0141523
# Epoch: 480 model: 1 loss 0.0142179
# Sz step finished
# Epoch: 481 model: 0 loss 0.0141107
# Epoch: 481 model: 1 loss 0.0141793
# Sz step finished
# Epoch: 482 model: 0 loss 0.0140733
# Epoch: 482 model: 1 loss 0.0141432
# Sz step finished
# Epoch: 483 model: 0 loss 0.0140376
# Epoch: 483 model: 1 loss 0.0141041
# Sz step finished
# Epoch: 484 model: 0 loss 0.0139974
# Epoch: 484 model: 1 loss 0.0140643
# Sz step finished
# Epoch: 485 model: 0 loss 0.0139616
# Epoch: 485 model: 1 loss 0.0140241
# Sz step finished
# Epoch: 486 model: 0 loss 0.0139223
# Epoch: 486 model: 1 loss 0.0139871
# Sz step finished
# Epoch: 487 model: 0 loss 0.0138838
# Epoch: 487 model: 1 loss 0.0139418
# Sz step finished
# Epoch: 488 model: 0 loss 0.013843
# Epoch: 488 model: 1 loss 0.0139066
# Sz step finished
# Epoch: 489 model: 0 loss 0.0138028
# Epoch: 489 model: 1 loss 0.0138652
# Sz step finished
# Epoch: 490 model: 0 loss 0.0137725
# Epoch: 490 model: 1 loss 0.0138264
# Sz step finished
# Epoch: 491 model: 0 loss 0.0137361
# Epoch: 491 model: 1 loss 0.0137811
# Sz step finished
# Epoch: 492 model: 0 loss 0.0137033
# Epoch: 492 model: 1 loss 0.0137467
# Sz step finished
# Epoch: 493 model: 0 loss 0.0136601
# Epoch: 493 model: 1 loss 0.0137085
# Sz step finished
# Epoch: 494 model: 0 loss 0.0136197
# Epoch: 494 model: 1 loss 0.0136697
# Sz step finished
# Epoch: 495 model: 0 loss 0.0135838
# Epoch: 495 model: 1 loss 0.0136339
# Sz step finished
# Epoch: 496 model: 0 loss 0.0135527
# Epoch: 496 model: 1 loss 0.0136002
# Sz step finished
# Epoch: 497 model: 0 loss 0.0135156
# Epoch: 497 model: 1 loss 0.013563
# Sz step finished
# Epoch: 498 model: 0 loss 0.0134788
# Epoch: 498 model: 1 loss 0.0135293
# Sz step finished
# Epoch: 499 model: 0 loss 0.0134413
# Epoch: 499 model: 1 loss 0.0134891
# Adversarial Trainining Finished

# %%
#Plot decisoin boundary
# %matplotlib inline                     

h=0.1
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

x_input = np.c_[xx.ravel(), yy.ravel()]
print(x_input.shape)

#Tracer()()

Z = 0
for net in model_list:
    Z = Z + net.forward(Variable(torch.from_numpy(x_input).float().cuda()))
#Z = model_list[1].forward(Variable(torch.from_numpy(x_input).float().cuda()))
#_, preds = torch.max(Z.data, 1)

_, preds = torch.max(Z.data, 1)
print(Z)
preds = preds.cpu().numpy()
#print(Z.data.cpu().numpy()[5000,:])

# here "model" is your model's prediction (classification) function
#Z = model(np.c_[xx.ravel(), yy.ravel()]) 

# Put the result into a color plot
print('xx shape', xx.shape)
preds = preds.reshape(xx.shape).astype(np.float)
print('type preds', preds.dtype)

#Tracer()()
#plt.figure()
print('max',np.max(preds), 'min', np.min(preds))
plt.contour(xx, yy, preds)
#plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
#plt.axis('off')
plt.scatter(x[:,0], x[:,1], c = colormap[y+1])

'''
if advtraining is True:
    x_adv_samples = np.concatenate(x_adv_set)
    y_adv_samples = np.concatenate(y_adv_set).astype(np.int)
'''
#adv_colors = np.array(['r', 'k'])
#plt.scatter(x_adv_samples[:,0], x_adv_samples[:,1], c=adv_colors[y_adv_samples])
plt.show()
# Out:
# (9476, 2)
# Variable containing:
# -6.3150e+01  4.9900e+01
# -6.2726e+01  4.9550e+01
# -6.2302e+01  4.9200e+01
#            ⋮
# -5.0603e+01  4.0388e+01
# -5.0947e+01  4.0712e+01
# -5.1987e+01  4.1595e+01
# [torch.cuda.FloatTensor of size 9476x2 (GPU 0)]
#
# xx shape (92, 103)
# type preds float64
# max 1.0 min 0.0

# %%
print(np.concatenate(y_adv_set))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-a79bd680e9fa> in <module>()
# ----> 1 print(np.concatenate(y_adv_set))
#
# ValueError: need at least one array to concatenate

# %%
import torch
a = torch.ones([2,1])
print(torch.norm(a, 2)**2)

# %%
print(net.state_dict())

# %%
a = np.array([[1,2], [3,4]])
b = np.random.normal(size=a.shape)
print(b)

# %%
from torch.optim import Optimizer
#TODO ref to entropy sgd to implement SGHMC, iteration steps inside the class
class SGHMC(Optimizer):
    def __init__(self, params, lr=0, momentum=0):
        defaults = dict(lr=lr, momentum=momentum)
        super(SGHMC, self).__init__(params, defaults)
    
    def __setstate__(self, state):
        super(SGHMC, self).__setstate__(state)
    
    def step(self, closure=None):
        loss = None
        if closure is not None:
            loss = closure()
        
        for group in self.param_groups:
            momentum = group['momentum']
            
            for p in group['params']:
                if p.grad is None:
                    continue
                d_p = p.grad.data
                
                param_state = self.state[p]
                
                if 'momentum_buffer' not in param_state:
                    buf = param_state['momentum_buffer'] = d_p.clone()
                else:
                    buf = param_state['momentum_buffer']
                    buf.mul_(momentum).add_(1, d_p)
                #Tracer()()
                p.data.add_(-group['lr'], d_p)
        return loss

# %%
a = torch.rand([2,3])

print(a)
print(a.mean((0)))
